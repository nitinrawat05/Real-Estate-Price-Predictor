# %%
import pandas as pd

# %%
data = pd.read_csv("realtor-data.csv")

# %%
data.head()
# Out:
#    brokered_by    status     price  bed  bath  acre_lot     street  \
# 0     103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1      52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2     103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3      31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4      34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
#
#          city        state  zip_code  house_size prev_sold_date
# 0    Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1    Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2  Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3       Ponce  Puerto Rico     731.0      1800.0            NaN
# 4    Mayaguez  Puerto Rico     680.0         NaN            NaN

# %%
data.tail()
# Out:
#          brokered_by status     price  bed  bath  acre_lot     street  \
# 2226377      23009.0   sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0   sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0   sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0   sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0   sold  580000.0  5.0   3.0      0.31   307704.0
#
#              city       state  zip_code  house_size prev_sold_date
# 2226377  Richland  Washington   99354.0      3600.0     2022-03-25
# 2226378  Richland  Washington   99354.0      1616.0     2022-03-25
# 2226379  Richland  Washington   99354.0      3200.0     2022-03-24
# 2226380  Richland  Washington   99354.0       933.0     2022-03-24
# 2226381  Richland  Washington   99354.0      3615.0     2022-03-23

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
data.describe()
# Out:
#         brokered_by         price           bed          bath      acre_lot  \
# count  2.221849e+06  2.224841e+06  1.745065e+06  1.714611e+06  1.900793e+06
# mean   5.293989e+04  5.241955e+05  3.275841e+00  2.496440e+00  1.522303e+01
# std    3.064275e+04  2.138893e+06  1.567274e+00  1.652573e+00  7.628238e+02
# min    0.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    2.386100e+04  1.650000e+05  3.000000e+00  2.000000e+00  1.500000e-01
# 50%    5.288400e+04  3.250000e+05  3.000000e+00  2.000000e+00  2.600000e-01
# 75%    7.918300e+04  5.500000e+05  4.000000e+00  3.000000e+00  9.800000e-01
# max    1.101420e+05  2.147484e+09  4.730000e+02  8.300000e+02  1.000000e+05
#
#              street      zip_code    house_size
# count  2.215516e+06  2.226083e+06  1.657898e+06
# mean   1.012325e+06  5.218668e+04  2.714471e+03
# std    5.837635e+05  2.895408e+04  8.081635e+05
# min    0.000000e+00  0.000000e+00  4.000000e+00
# ...

# %%
data.isna().sum()
# Out:
# brokered_by         4533
# status                 0
# price               1541
# bed               481317
# bath              511771
# acre_lot          325589
# street             10866
# city                1407
# state                  8
# zip_code             299
# house_size        568484
# prev_sold_date    734297
# dtype: int64

# %%
data.drop(columns=["brokered_by","zip_code","prev_sold_date"],inplace = True)

# %%
data.shape
# Out:
# (2226382, 9)

# %%
data.isna().sum()
data.isna().sum().sum()
# Out:
# 1900983

# %%
data.dropna(inplace = True)

# %%
data[data.duplicated()]
# Out:
#            status      price  bed  bath  acre_lot     street            city  \
# 3703     for_sale  1390000.0  3.0   5.0     14.48  1685783.0    Williamsburg
# 10417    for_sale    99000.0  2.0   1.0      5.00  1977450.0        Red Hook
# 14710    for_sale   575000.0  9.0   3.0      0.07   117325.0          Warren
# 19532    for_sale   399000.0  2.0   1.0      0.99  1527806.0       Rochester
# 26753    for_sale   750000.0  3.0   3.0      1.03  1230106.0            York
# ...           ...        ...  ...   ...       ...        ...             ...
# 2108206      sold   499000.0  3.0   3.0      0.24  1545436.0  Lake Arrowhead
# 2161599      sold   479000.0  2.0   2.0      2.39   688995.0      Middletown
# 2199910      sold   689950.0  2.0   2.0      0.02   350217.0         Seattle
# 2203665      sold  1897000.0  3.0   3.0      0.48  1146365.0       Sammamish
# 2224853      sold    99900.0  2.0   2.0      0.28  1656003.0        Republic
#
#                  state  house_size
# ...

# %%
data.duplicated().sum()
# Out:
# 535

# %%
data.drop_duplicates(inplace= True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data["status"].value_counts()
# Out:
# status
# for_sale    747459
# sold        608403
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
data["state"].value_counts().sort_values(ascending=False).head(10).plot(kind = "bar")
plt.title("Number of house by state")
plt.ylabel("Listing Number")
plt.xlabel("state")
plt.show()

# %%
data.groupby("state")["price"].mean().sort_values(ascending=False).astype(int)
# Out:
# state
# Virgin Islands          1947522
# Hawaii                  1491548
# District of Columbia    1209649
# California              1107572
# Colorado                 952486
# Utah                     914531
# Montana                  862815
# Connecticut              790488
# Massachusetts            754230
# Nevada                   751439
# Washington               727478
# Wyoming                  719581
# Guam                     717504
# Idaho                    689815
# New York                 657557
# Florida                  649977
# Oregon                   645160
# New Hampshire            640991
# Puerto Rico              632210
# Vermont                  557932
# Arizona                  552891
# Virginia                 546274
# Alaska                   541288
# New Jersey               541131
# Maine                    517891
# Rhode Island             511094
# Maryland                 502889
# South Carolina           485025
# Tennessee                485018
# ...

# %%
data.groupby("city")["price"].mean().sort_values(ascending=False).astype(int)
# Out:
# city
# International      2147483600
# Bolingbroke          45250000
# Bal Harbour          26585714
# Gulf Stream          21461250
# Woody Creek          20987500
#                       ...
# Otter Rock              10033
# Midwest                 10000
# Center Junction          8500
# Rowan                    7500
# Pilot Mound              6500
# Name: price, Length: 17114, dtype: int32

# %%
data.groupby(["state","city"])["price"].mean().sort_values(ascending=False).astype(int).reset_index()
# Out:
#             state           city       price
# 0      California  International  2147483600
# 1         Georgia    Bolingbroke    45250000
# 2        Colorado          Campo    45000000
# 3         Florida      Manalapan    28852833
# 4         Florida    Bal Harbour    26585714
# ...           ...            ...         ...
# 26255        Iowa         Curlew        7450
# 26256        Iowa    Pilot Mound        6500
# 26257        Iowa         Argyle        5500
# 26258    Illinois    Willow Hill           1
# 26259        Ohio   Walnut Creek           1
#
# [26260 rows x 3 columns]

# %%
data
# Out:
#            status     price  bed  bath  acre_lot     street           city  \
# 0        for_sale  105000.0  3.0   2.0      0.12  1962661.0       Adjuntas
# 1        for_sale   80000.0  4.0   2.0      0.08  1902874.0       Adjuntas
# 2        for_sale   67000.0  2.0   1.0      0.15  1404990.0     Juana Diaz
# 3        for_sale  145000.0  4.0   2.0      0.10  1947675.0          Ponce
# 5        for_sale  179000.0  4.0   3.0      0.46  1850806.0  San Sebastian
# ...           ...       ...  ...   ...       ...        ...            ...
# 2226377      sold  359900.0  4.0   2.0      0.33   353094.0       Richland
# 2226378      sold  350000.0  3.0   2.0      0.10  1062149.0       Richland
# 2226379      sold  440000.0  6.0   3.0      0.50   405677.0       Richland
# 2226380      sold  179900.0  2.0   1.0      0.09   761379.0       Richland
# 2226381      sold  580000.0  5.0   3.0      0.31   307704.0       Richland
#
#                state  house_size
# 0        Puerto Rico       920.0
# ...

# %%
data.select_dtypes(include =["number"]).corr()["price"]
# Out:
# price         1.000000
# bed           0.117585
# bath          0.208868
# acre_lot      0.005304
# street        0.000481
# house_size    0.073849
# Name: price, dtype: float64

# %% [markdown]
# Bathrooms: Weak positive correlation with price, indicating a slight increase in price with more bathrooms.
#
# Street: Almost no correlation with price, showing it has little to no impact on property value.
#
# Conclusion: Property features like bathrooms modestly influence price, while street names are largely irrelevant.

# %%
X = data[["bed","bath","house_size"]]

# %%
y = data["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1084689, 3)
# (271173, 3)
# (1084689,)
# (271173,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train
# Out:
#          bed  bath  house_size
# 113863   4.0   3.0      3274.0
# 1210712  2.0   3.0      2468.0
# 1948987  2.0   1.0       728.0
# 898607   4.0   3.0      1898.0
# 377965   3.0   2.0      1092.0
# ...      ...   ...         ...
# 1157492  2.0   1.0      1200.0
# 924130   5.0   5.0      4339.0
# 1330983  2.0   2.0      1459.0
# 1337502  4.0   2.0      2010.0
# 718696   2.0   2.0      1364.0
#
# [1084689 rows x 3 columns]

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 0.46690068,  0.34864229,  0.27493231],
#        [-1.0535536 ,  0.34864229,  0.08282113],
#        [-1.0535536 , -1.17199665, -0.3319102 ],
#        ...,
#        [-1.0535536 , -0.41167718, -0.15767537],
#        [ 0.46690068, -0.41167718, -0.02634379],
#        [-1.0535536 , -0.41167718, -0.18031875]])

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 339855.3454015816

# %%
joblib.dump(lr,"model.pkl")
# Out:
# ['model.pkl']
